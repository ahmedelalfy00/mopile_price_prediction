# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOADING DATASET

data=pd.read_csv('mobile_price.csv')

df=pd.DataFrame(data)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
#EXPLORATORY SOME INFORMATION ABOUT DATASET


df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.shape
# Out:
# (1868, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1868 entries, 0 to 1867
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1868 non-null   int64
#  1   blue           1868 non-null   int64
#  2   clock_speed    1868 non-null   float64
#  3   dual_sim       1868 non-null   int64
#  4   fc             1868 non-null   int64
#  5   four_g         1868 non-null   int64
#  6   int_memory     1868 non-null   int64
#  7   m_dep          1868 non-null   float64
#  8   mobile_wt      1868 non-null   int64
#  9   n_cores        1868 non-null   int64
#  10  pc             1868 non-null   int64
#  11  px_height      1868 non-null   int64
#  12  px_width       1868 non-null   int64
#  13  ram            1868 non-null   int64
#  14  sc_h           1868 non-null   int64
#  15  sc_w           1868 non-null   int64
#  16  talk_time      1868 non-null   int64
#  17  three_g        1868 non-null   int64
# ...

# %%
# We have 8 categorical variables: n_cores , price_range, blue, dual_sim, four_g, three_g, touch_screen, wifi

# We have 13 numeric variables: battery_power, clock_speed, fc, int_memory, m_dep,
# mobile_wt, pc, px_height, px_width, ram, talk_time, sc_h, sc_w

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1868.000000  1868.000000  1868.000000  1868.000000  1868.000000
# mean     1239.870985     0.496253     1.519058     0.511242     4.323340
# std       440.491493     0.500120     0.815589     0.500007     4.354824
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       851.750000     0.000000     0.700000     0.000000     1.000000
# 50%      1230.500000     0.000000     1.500000     1.000000     3.000000
# 75%      1617.000000     1.000000     2.200000     1.000000     7.000000
# max      1998.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  1868.000000  1868.000000  1868.000000  1868.000000  1868.000000  ...
# mean      0.520878    32.199679     0.501392   140.517666     4.511242  ...
# std       0.499698    18.160543     0.289188    35.361447     2.282272  ...
# ...

# %%
#Checking for null values


df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#There are no null values in the dataset
msno.bar(df, figsize = (16,5),color = "green")
plt.show()

# %%
#Checking the variance

df.var()
# Out:
# battery_power    1.940328e+05
# blue             2.501199e-01
# clock_speed      6.651856e-01
# dual_sim         2.500075e-01
# fc               1.896449e+01
# four_g           2.496978e-01
# int_memory       3.298053e+02
# m_dep            8.362956e-02
# mobile_wt        1.250432e+03
# n_cores          5.208765e+00
# pc               3.672535e+01
# px_height        1.943569e+05
# px_width         1.863430e+05
# ram              1.179635e+06
# sc_h             1.770302e+01
# sc_w             1.911704e+01
# talk_time        2.969257e+01
# three_g          1.815698e-01
# touch_screen     2.501199e-01
# wifi             2.500992e-01
# price_range      1.256970e+00
# dtype: float64

# %%
# Duplicate Values Detection
df.duplicated().sum()
# Out:
# 0

# %%
#The dataset does not contain duplicate samples.

# %%
#
plt.figure(figsize = (12,6))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()

# %%
df.corr()['price_range']
# Out:
# battery_power    0.192926
# blue             0.019180
# clock_speed     -0.008084
# dual_sim         0.020795
# fc               0.023938
# four_g           0.026351
# int_memory       0.045992
# m_dep            0.007716
# mobile_wt       -0.036415
# n_cores          0.004765
# pc               0.032991
# px_height        0.158777
# px_width         0.168441
# ram              0.917602
# sc_h             0.023843
# sc_w             0.048406
# talk_time        0.027737
# three_g          0.027472
# touch_screen    -0.030643
# wifi             0.024720
# price_range      1.000000
# Name: price_range, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#columns of price_range      
df.price_range.value_counts()
# Out:
# 3    474
# 2    473
# 0    466
# 1    455
# Name: price_range, dtype: int64

# %%
a=sns.countplot(data=df,x="price_range",palette="Greys")
plt.show()

# %%
#columns of blue
df.blue.value_counts()
print('\n 1 there is bluetooth=',df.blue.value_counts()[0],"\n",
      '0 there is not bluetooth=',df.blue.value_counts()[1])
# Out:
#  1 there is bluetooth= 941
#  0 there is not bluetooth= 927

# %%
a=sns.countplot(data=df,x="blue",palette="Greys")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of dual_sim

df.dual_sim.value_counts()
print('\n 1 there is dual sim=',df.dual_sim.value_counts()[0],"\n",
      '0 there is not dual sim=',df.dual_sim.value_counts()[1])
# Out:
#  1 there is dual sim= 913
#  0 there is not dual sim= 955

# %%
a=sns.countplot(data=df,x="dual_sim",palette="Greys")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of four_g

df.four_g.value_counts()
print('\n 0 there is 4G =',df.four_g.value_counts()[0],"\n",
      '1 there is not 4G=',df.four_g.value_counts()[1])
# Out:
#  0 there is 4G = 895
#  1 there is not 4G= 973

# %%
a=sns.countplot(data=df,x="four_g",palette="Greys")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of three_g

df.three_g.value_counts()
print('\n 0 there is not 3G =',df.three_g.value_counts()[0],"\n",
      '1 there is 3G=',df.three_g.value_counts()[1])
# Out:
#  0 there is not 3G = 445
#  1 there is 3G= 1423

# %%
a=sns.countplot(data=df,x="three_g",palette="Greys")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of touch_screen
df.touch_screen.value_counts()
print('\n 0 there is not touch_screen ',df.touch_screen.value_counts()[0],"\n",
      '1 there is touch_screen ',df.touch_screen.value_counts()[1])
# Out:
#  0 there is not touch_screen  927
#  1 there is touch_screen  941

# %%
a=sns.countplot(data=df,x="touch_screen",palette="Greys")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of wifi
df.wifi.value_counts()
print('\n 0 there is not wifi ',df.touch_screen.value_counts()[0],"\n",
      '1 there is wifi ',df.touch_screen.value_counts()[1])
# Out:
#  0 there is not wifi  927
#  1 there is wifi  941

# %%
a=sns.countplot(data=df,x="wifi",palette="Greys_r")
a.set_xticklabels(["There is not","There is"])
plt.show()

# %%
#columns of n_cores

df.n_cores.value_counts()
# Out:
# 4    251
# 7    251
# 5    236
# 2    233
# 3    233
# 8    231
# 1    225
# 6    208
# Name: n_cores, dtype: int64

# %%
a=sns.countplot(data=df,x="n_cores",palette="Greys_r")
plt.show()

# %%
# models

# %%
#Scale Data using Standard Scaler

# %%
#Define the features (X) and the output labels (y) of the given dataset:

x = df.drop('price_range', axis=1)
y = df['price_range']

# %%
#Perform train test split:

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
print('x_train shape: ', x_train.shape)
print('x_test shape: ', x_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ', y_test.shape)
# Out:
# x_train shape:  (1307, 20)
# x_test shape:  (561, 20)
# y_train shape:  (1307,)
# y_test shape:  (561,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

x_train = np.array(x_train)
x_test = np.array(x_test)

# %%
#Stacking technque to classify records
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier

# %%
svc = SVC(kernel='rbf', C=10)
LR = LogisticRegression(C=0.1, max_iter=3000)
DT = DecisionTreeClassifier(criterion='entropy')

# %%
models = [('DT',DT),('SVC',svc),('LR',LR)]
stack = StackingClassifier(models,final_estimator=LogisticRegression(), cv=5)

# %%
stack.fit(x_train,y_train)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# StackingClassifier(cv=5,
#                    estimators=[('DT',
#                                 DecisionTreeClassifier(criterion='entropy')),
#                                ('SVC', SVC(C=10)),
#                                ('LR',
#                                 LogisticRegression(C=0.1, max_iter=3000))],
#                    final_estimator=LogisticRegression())

# %%
stack.score(x_train,y_train)
# Out:
# 0.9770466717674062

# %%
stack.score(x_test,y_test)
# Out:
# 0.9518716577540107

# %%
##grid_search

# %%
# hyper parameter tuning

grid_params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(DT, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'min_samples_leaf': 3,
#  'min_samples_split': 5}

# %%
grid_search.best_score_
# Out:
# 0.8568980140972771

# %%
y_pred = best_model.predict(x_test)

# %%
from sklearn.metrics import precision_score, auc, roc_curve, classification_report

# %%
precision_score(y_test,y_pred, average='micro')
# Out:
# 0.875222816399287

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       142
#            1       0.84      0.86      0.85       134
#            2       0.84      0.76      0.80       146
#            3       0.87      0.93      0.90       139
#
#     accuracy                           0.88       561
#    macro avg       0.87      0.88      0.87       561
# weighted avg       0.87      0.88      0.87       561

# %%
##AUC FOR MULTICLASS
from sklearn.metrics import roc_auc_score

y_pred_prob = best_model.predict_proba(x_test)
auc_score = roc_auc_score(y_test, y_pred_prob, multi_class='ovr')
print("AUC:", auc_score)
# Out:
# AUC: 0.9304807705052089

# %%
#ROC FOR MULTICLASS
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1], pos_label=1)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
test_df = pd.read_csv('mobile_price_test_hidden.csv')
test_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            950     0          0.5         0   6       1          55    0.1
# 1            948     0          1.5         1   6       0          18    0.3
# 2           1328     1          0.5         0   5       1          27    0.3
# 3           1447     0          0.5         0   3       0          40    0.7
# 4           1973     1          0.5         1   3       0          21    0.8
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        124        8   7         86      1681  1305     6     5          4
# 1        119        4   7        340      1728  2926    17    13          9
# 2        144        3  18        602      1156  2674     7     2          5
# 3        184        2   5        963      1062   471     8     4         20
# 4         95        8   7        127       507  1724    12    10          8
#
#    three_g  touch_screen  wifi
# ...

# %%
test_pred = best_model.predict(test_df)
test_pred
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#       dtype=int64)

# %%
test_pred_df = pd.DataFrame(test_pred)
test_pred_df
# Out:
#      0
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# ..  ..
# 127  3
# 128  3
# 129  3
# 130  3
# 131  3
#
# [132 rows x 1 columns]

# %%
test_pred_df.to_csv('prediction_AhmedEsmat.csv', index=False)
